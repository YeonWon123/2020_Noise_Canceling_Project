# %%
# Code By adityatb at https://github.com/adityatb/noise-reduction-using-rnn
# LSTM method test.
# Maintain by ShYy, 2018.
import tensorflow as tf
import scipy
import scipy.signal as signal
import numpy as np
import os, random, sys
import scipy.io.wavfile as wav
import math
import pandas as pd
import matplotlib.pyplot as plt 
os.environ['CUDA_VISIBLE_DEVICES'] = '2'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd /content/gdrive/My Drive/Data/
# Out:
# /content/gdrive/My Drive/Data

# %%
os.getcwd()
# Out:
# '/content/gdrive/My Drive/Data'

# %% [markdown]
# ## 함수정의부

# %%
#filename을 입력받아 앞에서부터 len(filename)-11 까지만 남긴 뒤 _voice 추가
def formatFilename(filename):
    return filename[:len(filename) - 11] + "_voice.wav"

# Strip away the _xnoise.wav part of the filename, and append _voice.wav to obtain clean voice counterpart

def create_final_sequence(sequence, max_length):
    a, b = sequence.shape
    extra_len = max_length - b
    null_mat = np.zeros((len(sequence), extra_len), dtype=np.float32)
    sequence = np.concatenate((sequence, null_mat), axis=1)
    return sequence


def sequentialized_spectrum(batch):   #여기서 batch는 데이터가 들어있는 repository를 의미한다.
    # Get maximum length of batch
    t = []
    t_vec = []
    Sxx_Vec = []
    for each in batch:
        _, t, Sxx_Vec_Temp = signal.stft(each, fs=rate_repository[0], nperseg=stft_size, return_onesided = False) #signal module의 stft사용후 frequency, time, Zxx가 생성됨
        t_vec.append(t)
        Sxx_Vec.append(Sxx_Vec_Temp)
    maximum_length = findMaxlen(t_vec)

    max_run_total = int(math.ceil(float(maximum_length) / sequence_length))
    final_data = np.zeros([len(batch), max_run_total, stft_size, sequence_length])
    true_time = np.zeros([len(batch), max_run_total])

    # Read in a file and compute spectrum
    # for batch_idx, each_set in enumerate(batch):
    for batch_idx, Sxx in enumerate(Sxx_Vec):
        # f, t, Sxx = signal.stft(each_set, fs=rate_repository[0], nperseg=stft_size, return_onesided = False)

        # Magnitude and Phase Spectra
        Mag = Sxx.real
        t = t_vec[batch_idx]
        # Phase = Sxx.imag

        # Break up the spectrum in sequence_length sized data
        run_full_steps = float(len(t)) / sequence_length  #3.1
        run_total = int(math.ceil(run_full_steps))      #4

        # Run a loop long enough to break up all the data in the file into chunks of sequence_size
        for step in range(2): #100의자리 한번 10의 자리에서 한번, 총두번 실행

            begin_point = step * sequence_length
            end_point = begin_point + sequence_length

            m, n = Mag[:, begin_point:end_point].shape

            # Store each chunk sequentially in a new array, accounting for zero padding when close to the end of the file
            if n == (sequence_length*(math.floor(run_full_steps))):
                final_data[batch_idx, step, :, :] = np.copy(Mag[:, begin_point:end_point])
                true_time[batch_idx, step] = n
            else:
                final_data[batch_idx, step, :, :] = np.copy(create_final_sequence(Mag[:, begin_point:end_point], sequence_length))
                true_time[batch_idx, step] = n

    final_data = np.transpose(final_data, (0, 1, 3, 2))

    return final_data, true_time, maximum_length

def findMaxlen(data_vec):
    max_ = 0
    for each in data_vec:
        if len(each) > max_:
            max_ = len(each)
    return max_

# %%
def sequentialized_spectrum(batch):   #여기서 batch는 데이터가 들어있는 repository를 의미한다.
    # Get maximum length of batch
    t = []
    t_vec = []
    Sxx_Vec = []
    for each in batch:
        _, t, Sxx_Vec_Temp = signal.stft(each, fs=rate_repository[0], nperseg=stft_size, return_onesided = False) #signal module의 stft사용후 frequency, time, Zxx가 생성됨
        t_vec.append(t)
        Sxx_Vec.append(Sxx_Vec_Temp)
    
    maximum_length = findMaxlen(t_vec)
    max_run_total = int(math.ceil(float(maximum_length) / sequence_length))  #trainig data중 최대의 길이를 100으로 나눈 값
    #final_data = np.zeros([len(batch), max_run_total, stft_size, sequence_length])
    #true_time = np.zeros([len(batch), max_run_total])
    
    #모든길이를 400으로 고정
    #true_time은 어떻게 해줘야하나... 각 시간 정보만 넣으면 되므로? 1로 설정(일단)
    final_data = np.zeros([len(file_repository), stft_size, max_run_total*sequence_length])
    true_time = np.zeros([len(file_repository), 1])

    # Read in a file and compute spectrum
    # for batch_idx, each_set in enumerate(batch):
    for batch_idx, Sxx in enumerate(Sxx_Vec):

        # Magnitude and Phase Spectra
        Mag = Sxx.real
        t = t_vec[batch_idx]  #왜 굳이? 옮기는건지는 모르겠음 아무튼 t와 t_vec은 동일
        # Phase = Sxx.imag

        # Break up the spectrum in sequence_length sized data
        #해당 인덱스에 해당하는 Audio의 길이 = run_full_step 즉 total time step 이라고 생각하면댐
        run_full_steps = float(len(t)) / sequence_length #311/100 = 3.11 -> 4 
        run_total = int(math.ceil(run_full_steps))  #ceil 올림함수
        run_floor = int(math.floor(run_full_steps))

        #final_data[batch_idx,:,:] = np.copy(create_final_sequence(Mag, run_total*sequence_length))
        final_data[batch_idx,:,:] = np.copy(create_final_sequence(Mag, 400))
        true_time[batch_idx] = 400

    final_data = np.transpose(final_data, (0, 2, 1))

    return final_data, true_time, maximum_length

# %% [markdown]
# ## modeling에 필요한 변수들 선언

# %%
# ----------------- Begin Vars --------------------- #

# Training data directories
traindata = os.getcwd() + "/Training/NoiseAdded3/"
voicedata = os.getcwd() + "/Training/HumanVoices/"
checkpoints = os.getcwd() + "/TF_Checkpoints/"
modelOutput = os.getcwd() + "/Testing/ModelOutput5"
# NormConstant
norm_factor = (1 / 32768.0)

# Spectrogram Parameters
stft_size = 1024

# RNN Specs
sequence_length = 100
batch_size = 100
learning_rate = 0.001
epochs = 250
# number_of_layers = 3

# Tensorflow vars + Graph and LSTM Params --------------------------------------------------------------- tf 1.0 model 생성 시작 -----------------------------------------------------


# Temp_data_variables
no_of_files = 0
temp_list = []
final_data = []
sequence_length_id = 0

# Repositories
file_repository = []
rate_repository = []
clean_repository = []

# Selected vectors
files_vec = []
clean_files_fin_vec = []
clean_files_vec = []

# %% [markdown]
# # training Data 들을 읽어와서 list에 저장

# %%
# ------------------- Read all data to memory creating a repository of mixture and clean files --------------------- #
#필요한 것, input 값들(noiseadded, humanvoice)
os.chdir(traindata)
# for file_iter in range(traindata):

# Buffer training data to memory for faster execution:
for root, _, files in os.walk(traindata):
    files = sorted(files)
    no_of_files = len(files)
    
    #files는 NoiseAdded data들을 의미하며 배치사이즈가 training data size보다 크면 말이 안되니까 여기서 에러처리
    if batch_size > no_of_files:
        sys.exit("Error: batch_size cannot be more than number of files in the training directory")

    #files를 읽어와 data와 samplingrate를 각각 리스트에 저장
    for f in files:
        if f.endswith(".wav"):
            temp_list.append(f)
            srate, data = wav.read(os.path.join(root, f))
            file_repository.append(data)
            rate_repository.append(srate)

# %%
# Generate a vector of file names that are clean files
#map은 (함수,인자) 를 입력으로 받고 들어온 모든 인자에 대해 함수를 실행시켜 리스트형태로 반환시켜주는 함수이다 고로 들어온 temp_list 인자들에 대해 formatFilename이 실행된다
#간단히 말하면 기존의 이름을 바꾸는 역할을 한다
clean_files_vec = list(map(formatFilename, temp_list))

#clean한 목소리 데이터들을 clean_repasitory에 저장
for root, _, files in os.walk(voicedata):
    files = sorted(files)
    for each in files:  #each 는 file하나하나 총 2000
        if each.endswith(".wav"): #each가 .wav로 끝난다면
            for name in clean_files_vec:  #clean_files_vec 에있는 
                if each == name:
                    srate2, data2 = wav.read(os.path.join(root, name))
                    clean_repository.append(data2)

# %% [markdown]
# file_repository : training data들이 저장되어있음
#
# rate_repository : sampling rate들이 저장되어있음 (모두 16000 으로 동일한값)
#
# clean_repository : noise가 없는 사람목소리 model fitting시 label 로쓰임

# %% [markdown]
# ## sequentialized_spectrum 함수를 이용 푸리에 트랜스폼 실행

# %%
#모든 배열의 원소에 norm_factor를 곱한다. sequentialized_spectrum함수를
for file_iter in range(len(file_repository)):
    i = random.randint(0, len(file_repository) - 1)
    files_vec.append(file_repository[i] * norm_factor)
    clean_files_fin_vec.append(clean_repository[i] * norm_factor)

# %%
    #stft_bach, clean_voice_batch를 생성
    stft_batch, sequence_length_id, maximum_length = sequentialized_spectrum(files_vec)

# %%
    clean_voice_batch, sequence_length_id_clean, maximum_length_clean = sequentialized_spectrum(clean_files_fin_vec)

# %%
#용량이너무 커서 실패
#np.save('/content/gdrive/My Drive/Data/Testing/npArray_data/stft_batch', stft_batch)
#np.save('/content/gdrive/My Drive/Data/Testing/npArray_data/clean_voice_batch', clean_voice_batch)
#np.save('/content/gdrive/My Drive/Data/Testing/npArray_data/sequence_leng_id_clean', sequence_length_id_clean)
#np.save('/content/gdrive/My Drive/Data/Testing/npArray_data/maximum_length_clean', maximum_length_clean)
#np.save('/content/gdrive/My Drive/Data/Testing/npArray_data/maximum_length', maximum_length)

# %%
#load 시 이를 사용
#loaded_x = np.load('./saved_x.npy')

# %%
print(len(file_repository))
print(len(clean_repository))

# %% [markdown]
# ## 트레이닝셋과 테스트셋 만들기

# %% [markdown]
# stft_batch 는 x_data로,
#
# clean_voice_batch 는 y_data로 사용

# %%
X_train = stft_batch
Y_train = clean_voice_batch

# %% [markdown]
# # 모델형성

# %%
from keras.layers import LSTM
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input, Dense, LSTM, TimeDistributed
from keras import layers
import keras.backend as K
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# %%
#Model 생성, 층추가

model = Sequential() # Sequeatial Model
model.add(layers.LSTM(512, input_shape=(400, 1024),return_sequences=True)) # (timestep, feature)
model.add(layers.Dense(1024))

model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()

# %%
#model 폴더생성
model_path = '/content/gdrive/My Drive/Data/Testing/model4/'
if not os.path.exists(model_path):
  os.mkdir(model_path)

#Validation점수가 좋아지지않으면 중지
early_stopping = EarlyStopping(monitor='val_loss', patience=3)

#Vailidation 점수가 가장 좋은 모델만 저장
model_file_path = model_path + 'Epoch_{epoch:03d}_Val_{val_loss:.3f}.hdf5'
checkpoint = ModelCheckpoint(filepath=model_file_path, monitor='val_loss', verbose=1, save_best_only=True,)

# %%
os.getcwd()
# Out:
# '/content/gdrive/My Drive/Data/Training/NoiseAdded3'

# %%
#early_stop = EarlyStopping(monitor='loss', patience=1, verbose=1)
"""
model.fit(mini_x_data, mini_y_data, epochs=100,
          batch_size=1, verbose=1, callbacks=[early_stop])
"""
EPOCH = 100
BATCH_SIZE = 20
filename = model_path + '/checkpoint-epoch-{}-batch-{}-trial-001.h5'.format(EPOCH, BATCH_SIZE)

history = model.fit(X_train, Y_train,
      epochs=EPOCH, 
      batch_size= BATCH_SIZE,
      validation_split = 0.1,
      shuffle = True,
      callbacks=[checkpoint, early_stopping], # checkpoint 콜백
     )
# Out:
# Epoch 1/100
# 90/90 [==============================] - ETA: 0s - loss: 1.7519e-05
# Epoch 00001: val_loss improved from inf to 0.00002, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_001_Val_0.000.hdf5
# 90/90 [==============================] - 95s 1s/step - loss: 1.7519e-05 - val_loss: 1.7798e-05
# Epoch 2/100
# 90/90 [==============================] - ETA: 0s - loss: 1.6878e-05
# Epoch 00002: val_loss improved from 0.00002 to 0.00002, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_002_Val_0.000.hdf5
# 90/90 [==============================] - 100s 1s/step - loss: 1.6878e-05 - val_loss: 1.7046e-05
# Epoch 3/100
# 90/90 [==============================] - ETA: 0s - loss: 1.6227e-05
# Epoch 00003: val_loss improved from 0.00002 to 0.00002, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_003_Val_0.000.hdf5
# 90/90 [==============================] - 97s 1s/step - loss: 1.6227e-05 - val_loss: 1.6359e-05
# Epoch 4/100
# 90/90 [==============================] - ETA: 0s - loss: 1.5578e-05
# Epoch 00004: val_loss improved from 0.00002 to 0.00002, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_004_Val_0.000.hdf5
# 90/90 [==============================] - 96s 1s/step - loss: 1.5578e-05 - val_loss: 1.5646e-05
# Epoch 5/100
# 90/90 [==============================] - ETA: 0s - loss: 1.4904e-05
# Epoch 00005: val_loss improved from 0.00002 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_005_Val_0.000.hdf5
# 90/90 [==============================] - 96s 1s/step - loss: 1.4904e-05 - val_loss: 1.4901e-05
# Epoch 6/100
# 90/90 [==============================] - ETA: 0s - loss: 1.4195e-05
# Epoch 00006: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_006_Val_0.000.hdf5
# 90/90 [==============================] - 96s 1s/step - loss: 1.4195e-05 - val_loss: 1.4146e-05
# Epoch 7/100
# 90/90 [==============================] - ETA: 0s - loss: 1.3457e-05
# Epoch 00007: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_007_Val_0.000.hdf5
# 90/90 [==============================] - 97s 1s/step - loss: 1.3457e-05 - val_loss: 1.3311e-05
# Epoch 8/100
# 90/90 [==============================] - ETA: 0s - loss: 1.2730e-05
# Epoch 00008: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_008_Val_0.000.hdf5
# 90/90 [==============================] - 98s 1s/step - loss: 1.2730e-05 - val_loss: 1.2547e-05
# Epoch 9/100
# 90/90 [==============================] - ETA: 0s - loss: 1.2048e-05
# Epoch 00009: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_009_Val_0.000.hdf5
# 90/90 [==============================] - 98s 1s/step - loss: 1.2048e-05 - val_loss: 1.1857e-05
# Epoch 10/100
# 90/90 [==============================] - ETA: 0s - loss: 1.1420e-05
# Epoch 00010: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_010_Val_0.000.hdf5
# 90/90 [==============================] - 97s 1s/step - loss: 1.1420e-05 - val_loss: 1.1201e-05
# Epoch 11/100
# 90/90 [==============================] - ETA: 0s - loss: 1.0851e-05
# Epoch 00011: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_011_Val_0.000.hdf5
# 90/90 [==============================] - 95s 1s/step - loss: 1.0851e-05 - val_loss: 1.0625e-05
# Epoch 12/100
# 90/90 [==============================] - ETA: 0s - loss: 1.0341e-05
# Epoch 00012: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_012_Val_0.000.hdf5
# 90/90 [==============================] - 98s 1s/step - loss: 1.0341e-05 - val_loss: 1.0110e-05
# Epoch 13/100
# 90/90 [==============================] - ETA: 0s - loss: 9.8878e-06
# Epoch 00013: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_013_Val_0.000.hdf5
# 90/90 [==============================] - 97s 1s/step - loss: 9.8878e-06 - val_loss: 9.6440e-06
# Epoch 14/100
# 90/90 [==============================] - ETA: 0s - loss: 9.4781e-06
# Epoch 00014: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_014_Val_0.000.hdf5
# 90/90 [==============================] - 97s 1s/step - loss: 9.4781e-06 - val_loss: 9.2341e-06
# Epoch 15/100
# 90/90 [==============================] - ETA: 0s - loss: 9.1136e-06
# Epoch 00015: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_015_Val_0.000.hdf5
# 90/90 [==============================] - 99s 1s/step - loss: 9.1136e-06 - val_loss: 8.8603e-06
# Epoch 16/100
# 90/90 [==============================] - ETA: 0s - loss: 8.7843e-06
# Epoch 00016: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_016_Val_0.000.hdf5
# 90/90 [==============================] - 98s 1s/step - loss: 8.7843e-06 - val_loss: 8.5255e-06
# Epoch 17/100
# 90/90 [==============================] - ETA: 0s - loss: 8.4871e-06
# Epoch 00017: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_017_Val_0.000.hdf5
# 90/90 [==============================] - 97s 1s/step - loss: 8.4871e-06 - val_loss: 8.2243e-06
# Epoch 18/100
# 90/90 [==============================] - ETA: 0s - loss: 8.2180e-06
# Epoch 00018: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_018_Val_0.000.hdf5
# 90/90 [==============================] - 102s 1s/step - loss: 8.2180e-06 - val_loss: 7.9517e-06
# Epoch 19/100
# 90/90 [==============================] - ETA: 0s - loss: 7.9736e-06
# Epoch 00019: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_019_Val_0.000.hdf5
# 90/90 [==============================] - 98s 1s/step - loss: 7.9736e-06 - val_loss: 7.7000e-06
# Epoch 20/100
# 90/90 [==============================] - ETA: 0s - loss: 7.7519e-06
# Epoch 00020: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_020_Val_0.000.hdf5
# 90/90 [==============================] - 98s 1s/step - loss: 7.7519e-06 - val_loss: 7.4769e-06
# Epoch 21/100
# 90/90 [==============================] - ETA: 0s - loss: 7.5496e-06
# Epoch 00021: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_021_Val_0.000.hdf5
# 90/90 [==============================] - 100s 1s/step - loss: 7.5496e-06 - val_loss: 7.2693e-06
# Epoch 22/100
# 90/90 [==============================] - ETA: 0s - loss: 7.3645e-06
# Epoch 00022: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_022_Val_0.000.hdf5
# 90/90 [==============================] - 98s 1s/step - loss: 7.3645e-06 - val_loss: 7.0803e-06
# Epoch 23/100
# 90/90 [==============================] - ETA: 0s - loss: 7.1944e-06
# Epoch 00023: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_023_Val_0.000.hdf5
# 90/90 [==============================] - 98s 1s/step - loss: 7.1944e-06 - val_loss: 6.9070e-06
# Epoch 24/100
# 90/90 [==============================] - ETA: 0s - loss: 7.0380e-06
# Epoch 00024: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_024_Val_0.000.hdf5
# 90/90 [==============================] - 99s 1s/step - loss: 7.0380e-06 - val_loss: 6.7503e-06
# Epoch 25/100
# 90/90 [==============================] - ETA: 0s - loss: 6.8939e-06
# Epoch 00025: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_025_Val_0.000.hdf5
# 90/90 [==============================] - 96s 1s/step - loss: 6.8939e-06 - val_loss: 6.6032e-06
# Epoch 26/100
# 90/90 [==============================] - ETA: 0s - loss: 6.7619e-06
# Epoch 00026: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_026_Val_0.000.hdf5
# 90/90 [==============================] - 97s 1s/step - loss: 6.7619e-06 - val_loss: 6.4705e-06
# Epoch 27/100
# 90/90 [==============================] - ETA: 0s - loss: 6.6401e-06
# Epoch 00027: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_027_Val_0.000.hdf5
# 90/90 [==============================] - 98s 1s/step - loss: 6.6401e-06 - val_loss: 6.3453e-06
# Epoch 28/100
# 90/90 [==============================] - ETA: 0s - loss: 6.5272e-06
# Epoch 00028: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_028_Val_0.000.hdf5
# 90/90 [==============================] - 97s 1s/step - loss: 6.5272e-06 - val_loss: 6.2302e-06
# Epoch 29/100
# 90/90 [==============================] - ETA: 0s - loss: 6.4236e-06
# Epoch 00029: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_029_Val_0.000.hdf5
# 90/90 [==============================] - 97s 1s/step - loss: 6.4236e-06 - val_loss: 6.1261e-06
# Epoch 30/100
# 90/90 [==============================] - ETA: 0s - loss: 6.3253e-06
# Epoch 00030: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_030_Val_0.000.hdf5
# 90/90 [==============================] - 95s 1s/step - loss: 6.3253e-06 - val_loss: 6.0263e-06
# Epoch 31/100
# 90/90 [==============================] - ETA: 0s - loss: 6.2354e-06
# Epoch 00031: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_031_Val_0.000.hdf5
# 90/90 [==============================] - 98s 1s/step - loss: 6.2354e-06 - val_loss: 5.9362e-06
# Epoch 32/100
# 90/90 [==============================] - ETA: 0s - loss: 6.1509e-06
# Epoch 00032: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_032_Val_0.000.hdf5
# 90/90 [==============================] - 97s 1s/step - loss: 6.1509e-06 - val_loss: 5.8500e-06
# Epoch 33/100
# 90/90 [==============================] - ETA: 0s - loss: 6.0733e-06
# Epoch 00033: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_033_Val_0.000.hdf5
# 90/90 [==============================] - 97s 1s/step - loss: 6.0733e-06 - val_loss: 5.7729e-06
# Epoch 34/100
# 90/90 [==============================] - ETA: 0s - loss: 6.0009e-06
# Epoch 00034: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_034_Val_0.000.hdf5
# 90/90 [==============================] - 99s 1s/step - loss: 6.0009e-06 - val_loss: 5.6986e-06
# Epoch 35/100
# 90/90 [==============================] - ETA: 0s - loss: 5.9323e-06
# Epoch 00035: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_035_Val_0.000.hdf5
# 90/90 [==============================] - 97s 1s/step - loss: 5.9323e-06 - val_loss: 5.6298e-06
# Epoch 36/100
# 90/90 [==============================] - ETA: 0s - loss: 5.8693e-06
# Epoch 00036: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_036_Val_0.000.hdf5
# 90/90 [==============================] - 98s 1s/step - loss: 5.8693e-06 - val_loss: 5.5659e-06
# Epoch 37/100
# 90/90 [==============================] - ETA: 0s - loss: 5.8088e-06
# Epoch 00037: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_037_Val_0.000.hdf5
# 90/90 [==============================] - 99s 1s/step - loss: 5.8088e-06 - val_loss: 5.5062e-06
# Epoch 38/100
# 90/90 [==============================] - ETA: 0s - loss: 5.7517e-06
# Epoch 00038: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_038_Val_0.000.hdf5
# 90/90 [==============================] - 98s 1s/step - loss: 5.7517e-06 - val_loss: 5.4482e-06
# Epoch 39/100
# 90/90 [==============================] - ETA: 0s - loss: 5.6994e-06
# Epoch 00039: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_039_Val_0.000.hdf5
# 90/90 [==============================] - 97s 1s/step - loss: 5.6994e-06 - val_loss: 5.3970e-06
# Epoch 40/100
# 90/90 [==============================] - ETA: 0s - loss: 5.6492e-06
# Epoch 00040: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_040_Val_0.000.hdf5
# 90/90 [==============================] - 99s 1s/step - loss: 5.6492e-06 - val_loss: 5.3465e-06
# Epoch 41/100
# 90/90 [==============================] - ETA: 0s - loss: 5.6026e-06
# Epoch 00041: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_041_Val_0.000.hdf5
# 90/90 [==============================] - 99s 1s/step - loss: 5.6026e-06 - val_loss: 5.2965e-06
# Epoch 42/100
# 90/90 [==============================] - ETA: 0s - loss: 5.5580e-06
# Epoch 00042: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_042_Val_0.000.hdf5
# 90/90 [==============================] - 97s 1s/step - loss: 5.5580e-06 - val_loss: 5.2522e-06
# Epoch 43/100
# 90/90 [==============================] - ETA: 0s - loss: 5.5161e-06
# Epoch 00043: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_043_Val_0.000.hdf5
# 90/90 [==============================] - 99s 1s/step - loss: 5.5161e-06 - val_loss: 5.2132e-06
# Epoch 44/100
# 90/90 [==============================] - ETA: 0s - loss: 5.4771e-06
# Epoch 00044: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_044_Val_0.000.hdf5
# 90/90 [==============================] - 98s 1s/step - loss: 5.4771e-06 - val_loss: 5.1749e-06
# Epoch 45/100
# 90/90 [==============================] - ETA: 0s - loss: 5.4389e-06
# Epoch 00045: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_045_Val_0.000.hdf5
# 90/90 [==============================] - 97s 1s/step - loss: 5.4389e-06 - val_loss: 5.1360e-06
# Epoch 46/100
# 90/90 [==============================] - ETA: 0s - loss: 5.4040e-06
# Epoch 00046: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_046_Val_0.000.hdf5
# 90/90 [==============================] - 101s 1s/step - loss: 5.4040e-06 - val_loss: 5.0996e-06
# Epoch 47/100
# 90/90 [==============================] - ETA: 0s - loss: 5.3696e-06
# Epoch 00047: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_047_Val_0.000.hdf5
# 90/90 [==============================] - 98s 1s/step - loss: 5.3696e-06 - val_loss: 5.0650e-06
# Epoch 48/100
# 90/90 [==============================] - ETA: 0s - loss: 5.3384e-06
# Epoch 00048: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_048_Val_0.000.hdf5
# 90/90 [==============================] - 97s 1s/step - loss: 5.3384e-06 - val_loss: 5.0324e-06
# Epoch 49/100
# 90/90 [==============================] - ETA: 0s - loss: 5.3068e-06
# Epoch 00049: val_loss improved from 0.00001 to 0.00001, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_049_Val_0.000.hdf5
# 90/90 [==============================] - 98s 1s/step - loss: 5.3068e-06 - val_loss: 5.0012e-06
# Epoch 50/100
# 90/90 [==============================] - ETA: 0s - loss: 5.2783e-06
# Epoch 00050: val_loss improved from 0.00001 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_050_Val_0.000.hdf5
# 90/90 [==============================] - 101s 1s/step - loss: 5.2783e-06 - val_loss: 4.9715e-06
# Epoch 51/100
# 90/90 [==============================] - ETA: 0s - loss: 5.2499e-06
# Epoch 00051: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_051_Val_0.000.hdf5
# 90/90 [==============================] - 99s 1s/step - loss: 5.2499e-06 - val_loss: 4.9431e-06
# Epoch 52/100
# 90/90 [==============================] - ETA: 0s - loss: 5.2230e-06
# Epoch 00052: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_052_Val_0.000.hdf5
# 90/90 [==============================] - 99s 1s/step - loss: 5.2230e-06 - val_loss: 4.9177e-06
# Epoch 53/100
# 90/90 [==============================] - ETA: 0s - loss: 5.1979e-06
# Epoch 00053: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_053_Val_0.000.hdf5
# 90/90 [==============================] - 102s 1s/step - loss: 5.1979e-06 - val_loss: 4.8929e-06
# Epoch 54/100
# 90/90 [==============================] - ETA: 0s - loss: 5.1745e-06
# Epoch 00054: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_054_Val_0.000.hdf5
# 90/90 [==============================] - 100s 1s/step - loss: 5.1745e-06 - val_loss: 4.8679e-06
# Epoch 55/100
# 90/90 [==============================] - ETA: 0s - loss: 5.1506e-06
# Epoch 00055: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_055_Val_0.000.hdf5
# 90/90 [==============================] - 102s 1s/step - loss: 5.1506e-06 - val_loss: 4.8453e-06
# Epoch 56/100
# 90/90 [==============================] - ETA: 0s - loss: 5.1282e-06
# Epoch 00056: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_056_Val_0.000.hdf5
# 90/90 [==============================] - 103s 1s/step - loss: 5.1282e-06 - val_loss: 4.8222e-06
# Epoch 57/100
# 90/90 [==============================] - ETA: 0s - loss: 5.1077e-06
# Epoch 00057: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_057_Val_0.000.hdf5
# 90/90 [==============================] - 100s 1s/step - loss: 5.1077e-06 - val_loss: 4.8022e-06
# Epoch 58/100
# 90/90 [==============================] - ETA: 0s - loss: 5.0869e-06
# Epoch 00058: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_058_Val_0.000.hdf5
# 90/90 [==============================] - 102s 1s/step - loss: 5.0869e-06 - val_loss: 4.7796e-06
# Epoch 59/100
# 90/90 [==============================] - ETA: 0s - loss: 5.0676e-06
# Epoch 00059: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_059_Val_0.000.hdf5
# 90/90 [==============================] - 103s 1s/step - loss: 5.0676e-06 - val_loss: 4.7621e-06
# Epoch 60/100
# 90/90 [==============================] - ETA: 0s - loss: 5.0486e-06
# Epoch 00060: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_060_Val_0.000.hdf5
# 90/90 [==============================] - 101s 1s/step - loss: 5.0486e-06 - val_loss: 4.7436e-06
# Epoch 61/100
# 90/90 [==============================] - ETA: 0s - loss: 5.0314e-06
# Epoch 00061: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_061_Val_0.000.hdf5
# 90/90 [==============================] - 101s 1s/step - loss: 5.0314e-06 - val_loss: 4.7265e-06
# Epoch 62/100
# 90/90 [==============================] - ETA: 0s - loss: 5.0140e-06
# Epoch 00062: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_062_Val_0.000.hdf5
# 90/90 [==============================] - 103s 1s/step - loss: 5.0140e-06 - val_loss: 4.7077e-06
# Epoch 63/100
# 90/90 [==============================] - ETA: 0s - loss: 4.9971e-06
# Epoch 00063: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_063_Val_0.000.hdf5
# 90/90 [==============================] - 102s 1s/step - loss: 4.9971e-06 - val_loss: 4.6928e-06
# Epoch 64/100
# 90/90 [==============================] - ETA: 0s - loss: 4.9813e-06
# Epoch 00064: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_064_Val_0.000.hdf5
# 90/90 [==============================] - 102s 1s/step - loss: 4.9813e-06 - val_loss: 4.6781e-06
# Epoch 65/100
# 90/90 [==============================] - ETA: 0s - loss: 4.9651e-06
# Epoch 00065: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_065_Val_0.000.hdf5
# 90/90 [==============================] - 104s 1s/step - loss: 4.9651e-06 - val_loss: 4.6591e-06
# Epoch 66/100
# 90/90 [==============================] - ETA: 0s - loss: 4.9503e-06
# Epoch 00066: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_066_Val_0.000.hdf5
# 90/90 [==============================] - 102s 1s/step - loss: 4.9503e-06 - val_loss: 4.6441e-06
# Epoch 67/100
# 90/90 [==============================] - ETA: 0s - loss: 4.9361e-06
# Epoch 00067: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_067_Val_0.000.hdf5
# 90/90 [==============================] - 102s 1s/step - loss: 4.9361e-06 - val_loss: 4.6295e-06
# Epoch 68/100
# 90/90 [==============================] - ETA: 0s - loss: 4.9218e-06
# Epoch 00068: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_068_Val_0.000.hdf5
# 90/90 [==============================] - 102s 1s/step - loss: 4.9218e-06 - val_loss: 4.6157e-06
# Epoch 69/100
# 90/90 [==============================] - ETA: 0s - loss: 4.9087e-06
# Epoch 00069: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_069_Val_0.000.hdf5
# 90/90 [==============================] - 101s 1s/step - loss: 4.9087e-06 - val_loss: 4.6030e-06
# Epoch 70/100
# 90/90 [==============================] - ETA: 0s - loss: 4.8963e-06
# Epoch 00070: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_070_Val_0.000.hdf5
# 90/90 [==============================] - 101s 1s/step - loss: 4.8963e-06 - val_loss: 4.5916e-06
# Epoch 71/100
# 90/90 [==============================] - ETA: 0s - loss: 4.8827e-06
# Epoch 00071: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_071_Val_0.000.hdf5
# 90/90 [==============================] - 103s 1s/step - loss: 4.8827e-06 - val_loss: 4.5787e-06
# Epoch 72/100
# 90/90 [==============================] - ETA: 0s - loss: 4.8718e-06
# Epoch 00072: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_072_Val_0.000.hdf5
# 90/90 [==============================] - 102s 1s/step - loss: 4.8718e-06 - val_loss: 4.5649e-06
# Epoch 73/100
# 90/90 [==============================] - ETA: 0s - loss: 4.8598e-06
# Epoch 00073: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_073_Val_0.000.hdf5
# 90/90 [==============================] - 97s 1s/step - loss: 4.8598e-06 - val_loss: 4.5536e-06
# Epoch 74/100
# 90/90 [==============================] - ETA: 0s - loss: 4.8483e-06
# Epoch 00074: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_074_Val_0.000.hdf5
# 90/90 [==============================] - 100s 1s/step - loss: 4.8483e-06 - val_loss: 4.5422e-06
# Epoch 75/100
# 90/90 [==============================] - ETA: 0s - loss: 4.8372e-06
# Epoch 00075: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_075_Val_0.000.hdf5
# 90/90 [==============================] - 97s 1s/step - loss: 4.8372e-06 - val_loss: 4.5312e-06
# Epoch 76/100
# 90/90 [==============================] - ETA: 0s - loss: 4.8265e-06
# Epoch 00076: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_076_Val_0.000.hdf5
# 90/90 [==============================] - 100s 1s/step - loss: 4.8265e-06 - val_loss: 4.5214e-06
# Epoch 77/100
# 90/90 [==============================] - ETA: 0s - loss: 4.8161e-06
# Epoch 00077: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_077_Val_0.000.hdf5
# 90/90 [==============================] - 102s 1s/step - loss: 4.8161e-06 - val_loss: 4.5093e-06
# Epoch 78/100
# 90/90 [==============================] - ETA: 0s - loss: 4.8057e-06
# Epoch 00078: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_078_Val_0.000.hdf5
# 90/90 [==============================] - 100s 1s/step - loss: 4.8057e-06 - val_loss: 4.4995e-06
# Epoch 79/100
# 90/90 [==============================] - ETA: 0s - loss: 4.7961e-06
# Epoch 00079: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_079_Val_0.000.hdf5
# 90/90 [==============================] - 100s 1s/step - loss: 4.7961e-06 - val_loss: 4.4886e-06
# Epoch 80/100
# 90/90 [==============================] - ETA: 0s - loss: 4.7866e-06
# Epoch 00080: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_080_Val_0.000.hdf5
# 90/90 [==============================] - 104s 1s/step - loss: 4.7866e-06 - val_loss: 4.4790e-06
# Epoch 81/100
# 90/90 [==============================] - ETA: 0s - loss: 4.7777e-06
# Epoch 00081: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_081_Val_0.000.hdf5
# 90/90 [==============================] - 100s 1s/step - loss: 4.7777e-06 - val_loss: 4.4705e-06
# Epoch 82/100
# 90/90 [==============================] - ETA: 0s - loss: 4.7684e-06
# Epoch 00082: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_082_Val_0.000.hdf5
# 90/90 [==============================] - 102s 1s/step - loss: 4.7684e-06 - val_loss: 4.4618e-06
# Epoch 83/100
# 90/90 [==============================] - ETA: 0s - loss: 4.7603e-06
# Epoch 00083: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_083_Val_0.000.hdf5
# 90/90 [==============================] - 102s 1s/step - loss: 4.7603e-06 - val_loss: 4.4543e-06
# Epoch 84/100
# 90/90 [==============================] - ETA: 0s - loss: 4.7520e-06
# Epoch 00084: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_084_Val_0.000.hdf5
# 90/90 [==============================] - 100s 1s/step - loss: 4.7520e-06 - val_loss: 4.4446e-06
# Epoch 85/100
# 90/90 [==============================] - ETA: 0s - loss: 4.7443e-06
# Epoch 00085: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_085_Val_0.000.hdf5
# 90/90 [==============================] - 101s 1s/step - loss: 4.7443e-06 - val_loss: 4.4366e-06
# Epoch 86/100
# 90/90 [==============================] - ETA: 0s - loss: 4.7353e-06
# Epoch 00086: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_086_Val_0.000.hdf5
# 90/90 [==============================] - 104s 1s/step - loss: 4.7353e-06 - val_loss: 4.4285e-06
# Epoch 87/100
# 90/90 [==============================] - ETA: 0s - loss: 4.7282e-06
# Epoch 00087: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_087_Val_0.000.hdf5
# 90/90 [==============================] - 99s 1s/step - loss: 4.7282e-06 - val_loss: 4.4214e-06
# Epoch 88/100
# 90/90 [==============================] - ETA: 0s - loss: 4.7215e-06
# Epoch 00088: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_088_Val_0.000.hdf5
# 90/90 [==============================] - 101s 1s/step - loss: 4.7215e-06 - val_loss: 4.4146e-06
# Epoch 89/100
# 90/90 [==============================] - ETA: 0s - loss: 4.7134e-06
# Epoch 00089: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_089_Val_0.000.hdf5
# 90/90 [==============================] - 103s 1s/step - loss: 4.7134e-06 - val_loss: 4.4058e-06
# Epoch 90/100
# 90/90 [==============================] - ETA: 0s - loss: 4.7060e-06
# Epoch 00090: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_090_Val_0.000.hdf5
# 90/90 [==============================] - 101s 1s/step - loss: 4.7060e-06 - val_loss: 4.3990e-06
# Epoch 91/100
# 90/90 [==============================] - ETA: 0s - loss: 4.6987e-06
# Epoch 00091: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_091_Val_0.000.hdf5
# 90/90 [==============================] - 100s 1s/step - loss: 4.6987e-06 - val_loss: 4.3923e-06
# Epoch 92/100
# 90/90 [==============================] - ETA: 0s - loss: 4.6927e-06
# Epoch 00092: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_092_Val_0.000.hdf5
# 90/90 [==============================] - 103s 1s/step - loss: 4.6927e-06 - val_loss: 4.3840e-06
# Epoch 93/100
# 90/90 [==============================] - ETA: 0s - loss: 4.6862e-06
# Epoch 00093: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_093_Val_0.000.hdf5
# 90/90 [==============================] - 102s 1s/step - loss: 4.6862e-06 - val_loss: 4.3783e-06
# Epoch 94/100
# 90/90 [==============================] - ETA: 0s - loss: 4.6788e-06
# Epoch 00094: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_094_Val_0.000.hdf5
# 90/90 [==============================] - 102s 1s/step - loss: 4.6788e-06 - val_loss: 4.3712e-06
# Epoch 95/100
# 90/90 [==============================] - ETA: 0s - loss: 4.6727e-06
# Epoch 00095: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_095_Val_0.000.hdf5
# 90/90 [==============================] - 106s 1s/step - loss: 4.6727e-06 - val_loss: 4.3650e-06
# Epoch 96/100
# 90/90 [==============================] - ETA: 0s - loss: 4.6670e-06
# Epoch 00096: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_096_Val_0.000.hdf5
# 90/90 [==============================] - 102s 1s/step - loss: 4.6670e-06 - val_loss: 4.3594e-06
# Epoch 97/100
# 90/90 [==============================] - ETA: 0s - loss: 4.6612e-06
# Epoch 00097: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_097_Val_0.000.hdf5
# 90/90 [==============================] - 100s 1s/step - loss: 4.6612e-06 - val_loss: 4.3543e-06
# Epoch 98/100
# 90/90 [==============================] - ETA: 0s - loss: 4.6559e-06
# Epoch 00098: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_098_Val_0.000.hdf5
# 90/90 [==============================] - 104s 1s/step - loss: 4.6559e-06 - val_loss: 4.3472e-06
# Epoch 99/100
# 90/90 [==============================] - ETA: 0s - loss: 4.6495e-06
# Epoch 00099: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_099_Val_0.000.hdf5
# 90/90 [==============================] - 100s 1s/step - loss: 4.6495e-06 - val_loss: 4.3431e-06
# Epoch 100/100
# 90/90 [==============================] - ETA: 0s - loss: 4.6440e-06
# Epoch 00100: val_loss improved from 0.00000 to 0.00000, saving model to /content/gdrive/My Drive/Data/Testing/model4/Epoch_100_Val_0.000.hdf5
# 90/90 [==============================] - 102s 1s/step - loss: 4.6440e-06 - val_loss: 4.3374e-06

# %%
plt.plot(history.history['loss'],label='Train loss')
plt.plot(history.history['val_loss'],label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %% [markdown]
# 왜 validation loss가 더 적지..?

# %% [markdown]
# mini_x_data로 학습한 이유
#
# RNN 모델의 input shape는 (100,1024) 이다.
# 그러나 stft_batch는 (2000,4,100,1024) 이기 때문에
# mini_x_data = stft_batch[:,0,:,:] 으로 중간의 2번에 축의 데이터를 하나만 사용하였다.

# %%
maxTimeSteps = 4

# %%
#model.output 출력부분

# %% [markdown]
# Keras로 바꾼 부분은 여기까지
#
# model.predict로 최종 결과물 까지 확인해보고 싶으나
# 역변환이 제대로 되지않는것을 확인해 아직 구현하지 않음
# 추후 수정해야할 부분

# %% [markdown]
# # 원본을 그대로 복구해보기(inverse stft)
# stft_batch는 원본 데이터들을 stft시켜놓은 파일이다
# 이를 다른 과정을 거치지 않고 바로 역변환 시켜 보자.
# training data중 3개의 sample로 진행
#
# 수정된 부분 : sess.run([final_state, rnn_outputs], feed_dict=feed_dict) -> stft_batch[idx][timestep]
#
# 외 추가적으로 오류난 부분을 수정함
#
# 목적 : 역변환 code가 정상적으로 돌아가는지 확인

# %%
#(2000,400,1024) 로 출력될거라 예상

# %%
# Start Processing
for idx in range(3):

    outputData = np.zeros([1,stft_size, sequence_length])           # Transpose, [0, 1, 3, 2]
    #(1,1024,400)
    #변환이 안되는 이유!
    for timeStep in range(maxTimeSteps):
        rnn_outputs_value = stft_batch[idx][timeStep]
        rnn_outputs_value = np.expand_dims(rnn_outputs_value, axis = 0)           #오류가 예상되는 부분
        rnn_outputs_value = np.transpose(rnn_outputs_value, [0, 2, 1])
        outputData[0][timeStep] = rnn_outputs_value

    # Define outputData_STFT, link outputData List by timeStep in 1 dimension.-----------------------------------------------------------------------------
    outputData_STFT = np.zeros([stft_size, maximum_length])
    beginTime = 0
    endTime = 0

    for timeStep in range(maxTimeSteps):
        if(timeStep < maxTimeSteps - 1):
            endTime = beginTime + sequence_length
            outputData_STFT[:, beginTime : endTime] = outputData[0, timeStep, :, :]
        else:
            endTime = beginTime + int(sequence_length_id[0, timeStep])
            outputData_STFT[:, beginTime : endTime] = outputData[0, timeStep, :, 0 : (endTime - beginTime)]

        beginTime = beginTime + sequence_length

    # Compute ISTFT
    _, outputData_ISTFT = signal.istft(outputData_STFT, fs=16000, nperseg=stft_size, input_onesided = False)

    outputData_ISTFT = (outputData_ISTFT / norm_factor).real
    outputData_ISTFT = outputData_ISTFT.astype(np.int16)

    wav.write(modelOutput +'/file_'+ str(idx) +".wav", 16000 , outputData_ISTFT)
    print("Index: " + str(idx))

# %% [markdown]
# # 함수 도중에 쓰인 값을의 shape 확인
# 이를 토대로 model.predict값을 어떻게 적용시킬지 고민해보자

# %%
#원본파일파형
stft_batch[1][1].shape

# %%
#복구파일파형
outputData_STFT.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-81ef2ee8ae47> in <module>()
#       1 #복구파일파형
# ----> 2 outputData_STFT.shape
#
# NameError: name 'outputData_STFT' is not defined

# %%
rnn_outputs_value = stft_batch[0][1]
print(rnn_outputs_value)
print(rnn_outputs_value.shape)

# %%
rnn_outputs_value1 = np.expand_dims(rnn_outputs_value, axis = 0)           #오류가 예상되는 부분
print(rnn_outputs_value1)
print(rnn_outputs_value1.shape)

# %%
rnn_outputs_value2 = np.transpose(rnn_outputs_value1, [0, 2, 1])
print(rnn_outputs_value2)
print(rnn_outputs_value2.shape)

# %%
outputData[0][timeStep] = rnn_outputs_value2
print(outputData)
print(outputData.shape)

# %% [markdown]
# # Model을 적용시켜보기

# %%
modeloutput = model.predict(X_train)

# %%
modeloutput.shape
#(2000,1024,400)

# %%
#transpose(0,2,1)
#istft 실행
#Audio file 추출

# %%
modeloutput1 = np.expand_dims(modeloutput, axis = 1)
modeloutput1.shape

# %%
modeloutput2 = np.append(modeloutput1, modeloutput1[:,:,:,:], axis=1)
modeloutput2.shape

# %%
# Start Processing
for idx in range(3):

    outputData = np.zeros([1, stft_size, sequence_length])           # Transpose, [0, 1, 3, 2]

    #변환이 안되는 이유!
    for timeStep in range(maxTimeSteps):
      #뭘 뺴오는 거지??
        rnn_outputs_value = modeloutput2[idx]
        rnn_outputs_value = np.expand_dims(rnn_outputs_value, axis = 0)           #오류가 예상되는 부분
        rnn_outputs_value = np.transpose(rnn_outputs_value, [0, 2, 1])
        outputData[0] = rnn_outputs_value

  """
    # Define outputData_STFT, link outputData List by timeStep in 1 dimension.-----------------------------------------------------------------------------
    outputData_STFT = np.zeros([stft_size, maximum_length])
    beginTime = 0
    endTime = 0

    for timeStep in range(maxTimeSteps):
        if(timeStep < maxTimeSteps - 1):
            endTime = beginTime + sequence_length
            outputData_STFT[:, beginTime : endTime] = outputData[0, timeStep, :, :]
        else:
            endTime = beginTime + int(sequence_length_id[0, timeStep])
            outputData_STFT[:, beginTime : endTime] = outputData[0, timeStep, :, 0 : (endTime - beginTime)]

        beginTime = beginTime + sequence_length
  """

    # Compute ISTFT
    _, outputData_ISTFT = signal.istft(outputData[idx], fs=16000, nperseg=stft_size, input_onesided = False)

    outputData_ISTFT = (outputData_ISTFT / norm_factor).real
    outputData_ISTFT = outputData_ISTFT.astype(np.int16)

    wav.write(modelOutput +'/file_output'+ str(idx) +".wav", 16000 , outputData_ISTFT)
    print("Index: " + str(idx))

# %%
file_repository[0].shape

# %%
    wav.write(modelOutput +'/file_original_'+ str(0) +".wav", 16000 , file_repository[0])
    wav.write(modelOutput +'/file_original_'+ str(1) +".wav", 16000 , file_repository[1])
    wav.write(modelOutput +'/file_original_'+ str(2) +".wav", 16000 , file_repository[2])

# %%
_, t, Sxx_Vec_Temp = signal.stft(file_repository[0], fs=rate_repository[0], nperseg=stft_size, return_onesided = False) #signal module의 stft사용후 frequency, time, Zxx가 생성됨

# %%
print(file_repository[0].shape)
print(_.shape)
print(t.shape)
print(Sxx_Vec_Temp.shape)

# %%
#stft_size 란?
#311은 뭘 의미하는거지?

# %%
print(t)
plt.plot(Sxx_Vec_Temp)
plt.show()
