# %%
# This script aims to test the model using the Test Dataset seperated from source Dataset by CreateTestDataset.py
# Code by ShYy, 2018.

import scipy
import scipy.signal as signal
import numpy as np
import os
import random
import sys
import scipy.io.wavfile as wav
import math

# %%
# %tensorflow_version 1.8
import tensorflow as tf
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.8`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
# Get the source Human Voice file names by Noise Added file names.
def formatSrcFilename(filename):
    return filename[:len(filename) - 11] + "_voice.wav"

def formatOutputFilename(filename):
    return filename[:len(filename) - 11] + "_output.wav"

def sequentialized_spectrum(batch):
    # Get maximum length of batch
    t = []
    t_vec = []
    Sxx_Vec = []
    for each in batch:
        _, t, Sxx_Vec_Temp = signal.stft(each, fs=testNARateRepository[0], nperseg=stft_size, return_onesided = False)
        t_vec.append(t)
        Sxx_Vec.append(Sxx_Vec_Temp)
    maximum_length = findMaxlen(t_vec)

    max_run_total = int(math.ceil(float(maximum_length) / sequence_length))
    final_data = np.zeros([len(batch), max_run_total, stft_size, sequence_length])
    true_time = np.zeros([len(batch), max_run_total])

    # Read in a file and compute spectrum
    # for batch_idx, each_set in enumerate(batch):
    for batch_idx, Sxx in enumerate(Sxx_Vec):
        # f, t, Sxx = signal.stft(each_set, fs=rate_repository[0], nperseg=stft_size, return_onesided = False)

        # Magnitude and Phase Spectra
        Mag = Sxx.real
        t = t_vec[batch_idx]
        # Phase = Sxx.imag

        # Break up the spectrum in sequence_length sized data
        run_full_steps = float(len(t)) / sequence_length
        run_total = int(math.ceil(run_full_steps))

        # Run a loop long enough to break up all the data in the file into chunks of sequence_size
        for step in range(run_total):

            begin_point = step * sequence_length
            end_point = begin_point + sequence_length

            m, n = Mag[:, begin_point:end_point].shape

            # Store each chunk sequentially in a new array, accounting for zero padding when close to the end of the file
            if n == sequence_length:
                final_data[batch_idx, step, :, :] = np.copy(Mag[:, begin_point:end_point])
                true_time[batch_idx, step] = n
            else:
                final_data[batch_idx, step, :, :] = np.copy(create_final_sequence(Mag[:, begin_point:end_point], sequence_length))
                true_time[batch_idx, step] = n

    final_data = np.transpose(final_data, (0, 1, 3, 2))

    return final_data, true_time, maximum_length

def findMaxlen(data_vec):
    max_ = 0
    for each in data_vec:
        if len(each) > max_:
            max_ = len(each)
    return max_

def create_final_sequence(sequence, max_length):
    a, b = sequence.shape
    extra_len = max_length - b
    null_mat = np.zeros((len(sequence), extra_len), dtype=np.float32)
    sequence = np.concatenate((sequence, null_mat), axis=1)
    return sequence

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/My Drive/Data/
# Out:
# /content/gdrive/My Drive/Data

# %%
os.getcwd()
# Out:
# '/content/gdrive/My Drive/Data'

# %%
# Directories
humanVoice = os.getcwd() + "/Training/HumanVoices/"
testData = os.getcwd() + "/Testing/NoiseAdded/"
modelOutput = os.getcwd() + "/Testing/ModelOutput3/"
graphPath = os.getcwd() + "/TF_Checkpoints/ssep_model_increaseBatchSize.ckpt-499"

# Number of test files
testFileNum = 0

# File List
testNAFileList = []         # Test Dataset. Noise Added File List.
srcHVFileList = []          # Source Human Voice File List.
outputFileList = []         # Output File List

# File Repository
testNARateRepository = []
testNADataRepository = []
srcHVRateRepository = []
srcHVDataRepository = []

norm_factor = (1.0 / 32768.0)         # Let data map to -1 ~ 1 range for LSTM process

# %%
# Walk all test NA files to File List and File Repository.
for root, _, files in os.walk(testData):
    files = sorted(files)
    testFileNum = len(files)

    for f in files:
        if f.endswith(".wav"):
            testNAFileList.append(f)
            rate, data = wav.read(os.path.join(root, f))
            testNARateRepository.append(rate)
            testNADataRepository.append(data * norm_factor)

srcHVFileList = list(map(formatSrcFilename, testNAFileList))
outputFileList = list(map(formatOutputFilename, testNAFileList))

# Walk all source HV files to File Repository.
for root, _, files in os.walk(humanVoice):
    files = sorted(files)

    for f in files:
        if(f.endswith(".wav")):
            for name in srcHVFileList:
                if f == name:
                    rate, data = wav.read(os.path.join(root, f))
                    srcHVRateRepository.append(rate)
                    srcHVDataRepository.append(data * norm_factor)

# STFT Process Variables, also used in LSTM
sequence_length = 100
stft_size = 1024
batch_size = 1          # Set 1 for process 1 Wav file a time.

# %%
# Tensorflow vars + Graph and LSTM Params
input_data = tf.placeholder(tf.float32, [None, sequence_length, stft_size])
# clean_data = tf.placeholder(tf.float32, [None, sequence_length, stft_size])
sequence_length_tensor = tf.placeholder(tf.int32, (None))

# TF Graph Definition
lstm_cell = tf.contrib.rnn.BasicLSTMCell(stft_size, forget_bias = 1.0, state_is_tuple = True)
# stacked_lstm = tf.contrib.rnn.MultiRNNCell([[lstm_cell] for i in number_of_layers])
init_state = lstm_cell.zero_state(batch_size, tf.float32)
rnn_outputs, final_state = tf.nn.dynamic_rnn(lstm_cell, input_data, sequence_length=sequence_length_tensor, initial_state=init_state, time_major=False)
# mse_loss = tf.losses.mean_squared_error(rnn_outputs, clean_data)
# train_optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(mse_loss)
# train_optimizer = tf.train.AdagradOptimizer(learning_rate).minimize(mse_loss)
# train_optimizer = tf.train.AdagradDAOptimizer(learning_rate).minimize(mse_loss)
# train_optimizer = tf.train.AdamOptimizer(learning_rate).minimize(mse_loss)
saver = tf.train.Saver()

# Initialize TF Graph and Restore the Graph
init_op = tf.global_variables_initializer()  # initialize_all_variables()
gpu_options = tf.GPUOptions(allow_growth = True)            # Set session GPU using growing.
sess = tf.Session(config = tf.ConfigProto(gpu_options = gpu_options))
sess.run(init_op)
saver.restore(sess, graphPath)
print("\t***** TF GRAPH RESTORED *****")
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From <ipython-input-9-f798ebd7b242>:7: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-9-f798ebd7b242>:10: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/rnn_cell_impl.py:735: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/rnn_cell_impl.py:739: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/Data/TF_Checkpoints/ssep_model_increaseBatchSize.ckpt-499
# 	***** TF GRAPH RESTORED *****

# %%
# Start Processing
for idx in range(testFileNum):
    nowNAFile = []
    nowNAFile.append(testNADataRepository[idx])

    # Get NA stft repository.
    nowNAData_STFT, sequenceLengthID, maxLength = sequentialized_spectrum(nowNAFile)

    # Get Time Steps.
    maxTimeSteps = len(nowNAData_STFT[0])

    # Define outputData List to contain rnn_outputs_value.
    outputData = np.zeros([1,  maxTimeSteps, stft_size, sequence_length])           # Transpose, [0, 1, 3, 2]

    for timeStep in range(maxTimeSteps):
        feed_dict = {
            input_data : nowNAData_STFT[:, timeStep, :],
            sequence_length_tensor : sequenceLengthID[:, timeStep]
        }
        final_state_value, rnn_outputs_value = sess.run([final_state, rnn_outputs], feed_dict=feed_dict)
        print(rnn_outputs_value.shape)
        rnn_outputs_value = np.transpose(rnn_outputs_value, [0, 2, 1])
        outputData[0][timeStep] = rnn_outputs_value

    # Define outputData_STFT, link outputData List by timeStep in 1 dimension.-----------------------------------------------------------------------------
    outputData_STFT = np.zeros([stft_size, maxLength])
    beginTime = 0
    endTime = 0
    
    for timeStep in range(maxTimeSteps):
        if(timeStep < maxTimeSteps - 1):
            endTime = beginTime + sequence_length
            outputData_STFT[:, beginTime : endTime] = outputData[0, timeStep, :, :]
        else:
            endTime = beginTime + int(sequenceLengthID[0, timeStep])
            outputData_STFT[:, beginTime : endTime] = outputData[0, timeStep, :, 0 : (endTime - beginTime)]

        beginTime = beginTime + sequence_length

    # Compute ISTFT
    _, outputData_ISTFT = signal.istft(outputData_STFT, fs=testNARateRepository[0], nperseg=stft_size, input_onesided = False)

    outputData_ISTFT = (outputData_ISTFT / norm_factor).real
    outputData_ISTFT = outputData_ISTFT.astype(np.int16)

    #wav.write(modelOutput + outputFileList[idx], testNARateRepository[idx], outputData_ISTFT)
    print("Index: " + str(idx))
    print("\tOutput File: " + str(outputFileList[idx]))
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# (1, 100, 1024)
# Index: 9
# 	Output File: Ani_2_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 10
# 	Output File: Ani_2_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 11
# 	Output File: Ani_2_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 12
# 	Output File: Ani_2_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 13
# 	Output File: Ani_2_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 14
# 	Output File: Ani_2_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 15
# 	Output File: Ani_2_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 16
# 	Output File: Ani_2_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 17
# 	Output File: Ani_2_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 18
# 	Output File: Ani_2_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 19
# 	Output File: Ani_3_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 20
# 	Output File: Ani_3_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 21
# 	Output File: Ani_3_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 22
# 	Output File: Ani_3_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 23
# 	Output File: Ani_4_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 24
# 	Output File: Ani_4_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 25
# 	Output File: Ani_4_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 26
# 	Output File: Ani_4_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 27
# 	Output File: Ani_4_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 28
# 	Output File: Ani_4_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 29
# 	Output File: Ani_4_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 30
# 	Output File: Ani_4_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 31
# 	Output File: Ani_4_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 32
# 	Output File: Ani_4_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 33
# 	Output File: Ani_5_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 34
# 	Output File: Ani_5_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 35
# 	Output File: Ani_5_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 36
# 	Output File: Ani_5_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 37
# 	Output File: Ani_5_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 38
# 	Output File: Kenshin_1_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 39
# 	Output File: Kenshin_1_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 40
# 	Output File: Kenshin_1_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 41
# 	Output File: Kenshin_1_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 42
# 	Output File: Kenshin_1_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 43
# 	Output File: Kenshin_1_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 44
# 	Output File: Kenshin_1_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 45
# 	Output File: Kenshin_1_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 46
# 	Output File: Kenshin_1_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 47
# 	Output File: Kenshin_1_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 48
# 	Output File: Kenshin_1_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 49
# 	Output File: Kenshin_1_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 50
# 	Output File: Kenshin_1_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 51
# 	Output File: Kenshin_1_11_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 52
# 	Output File: Kenshin_2_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 53
# 	Output File: Kenshin_2_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 54
# 	Output File: Kenshin_2_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 55
# 	Output File: Kenshin_2_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 56
# 	Output File: Kenshin_2_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 57
# 	Output File: Kenshin_2_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 58
# 	Output File: Kenshin_2_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 59
# 	Output File: Kenshin_2_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 60
# 	Output File: Kenshin_2_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 61
# 	Output File: Kenshin_2_11_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 62
# 	Output File: Kenshin_3_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 63
# 	Output File: Kenshin_3_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 64
# 	Output File: Kenshin_3_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 65
# 	Output File: Kenshin_3_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 66
# 	Output File: Kenshin_3_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 67
# 	Output File: Kenshin_3_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 68
# 	Output File: Kenshin_3_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 69
# 	Output File: Kenshin_3_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 70
# 	Output File: Kenshin_3_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 71
# 	Output File: Kenshin_4_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 72
# 	Output File: Kenshin_4_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 73
# 	Output File: Kenshin_4_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 74
# 	Output File: Kenshin_4_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 75
# 	Output File: Kenshin_4_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 76
# 	Output File: Kenshin_4_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 77
# 	Output File: Kenshin_4_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 78
# 	Output File: Kenshin_4_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 79
# 	Output File: Kenshin_4_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 80
# 	Output File: Kenshin_4_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 81
# 	Output File: Kenshin_4_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 82
# 	Output File: Kenshin_4_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 83
# 	Output File: Kenshin_5_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 84
# 	Output File: Kenshin_5_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 85
# 	Output File: Kenshin_5_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 86
# 	Output File: Kenshin_5_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 87
# 	Output File: Kenshin_5_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 88
# 	Output File: Kenshin_5_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 89
# 	Output File: Kenshin_5_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 90
# 	Output File: Kenshin_5_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 91
# 	Output File: Kenshin_5_11_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 92
# 	Output File: Kenshin_5_12_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 93
# 	Output File: Kenshin_5_12_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 94
# 	Output File: Kenshin_5_13_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 95
# 	Output File: abjones_1_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 96
# 	Output File: abjones_1_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 97
# 	Output File: abjones_2_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 98
# 	Output File: abjones_2_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 99
# 	Output File: abjones_2_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 100
# 	Output File: abjones_2_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 101
# 	Output File: abjones_2_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 102
# 	Output File: abjones_2_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 103
# 	Output File: abjones_2_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 104
# 	Output File: abjones_2_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 105
# 	Output File: abjones_2_12_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 106
# 	Output File: abjones_3_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 107
# 	Output File: abjones_3_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 108
# 	Output File: abjones_3_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 109
# 	Output File: abjones_3_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 110
# 	Output File: abjones_3_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 111
# 	Output File: abjones_3_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 112
# 	Output File: abjones_3_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 113
# 	Output File: abjones_3_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 114
# 	Output File: abjones_3_11_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 115
# 	Output File: abjones_3_11_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 116
# 	Output File: abjones_3_12_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 117
# 	Output File: abjones_3_14_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 118
# 	Output File: abjones_4_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 119
# 	Output File: abjones_4_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 120
# 	Output File: abjones_4_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 121
# 	Output File: abjones_4_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 122
# 	Output File: abjones_4_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 123
# 	Output File: abjones_4_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 124
# 	Output File: abjones_4_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 125
# 	Output File: abjones_5_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 126
# 	Output File: abjones_5_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 127
# 	Output File: abjones_5_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 128
# 	Output File: abjones_5_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 129
# 	Output File: abjones_5_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 130
# 	Output File: abjones_5_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 131
# 	Output File: abjones_5_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 132
# 	Output File: abjones_5_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 133
# 	Output File: amy_10_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 134
# 	Output File: amy_10_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 135
# 	Output File: amy_10_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 136
# 	Output File: amy_10_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 137
# 	Output File: amy_10_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 138
# 	Output File: amy_10_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 139
# 	Output File: amy_10_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 140
# 	Output File: amy_10_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 141
# 	Output File: amy_11_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 142
# 	Output File: amy_11_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 143
# 	Output File: amy_11_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 144
# 	Output File: amy_11_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 145
# 	Output File: amy_11_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 146
# 	Output File: amy_12_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 147
# 	Output File: amy_12_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 148
# 	Output File: amy_12_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 149
# 	Output File: amy_12_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 150
# 	Output File: amy_12_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 151
# 	Output File: amy_13_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 152
# 	Output File: amy_13_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 153
# 	Output File: amy_13_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 154
# 	Output File: amy_13_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 155
# 	Output File: amy_13_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 156
# 	Output File: amy_14_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 157
# 	Output File: amy_14_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 158
# 	Output File: amy_14_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 159
# 	Output File: amy_14_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 160
# 	Output File: amy_14_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 161
# 	Output File: amy_14_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 162
# 	Output File: amy_14_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 163
# 	Output File: amy_14_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 164
# 	Output File: amy_15_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 165
# 	Output File: amy_15_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 166
# 	Output File: amy_15_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 167
# 	Output File: amy_15_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 168
# 	Output File: amy_15_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 169
# 	Output File: amy_15_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 170
# 	Output File: amy_15_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 171
# 	Output File: amy_15_12_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 172
# 	Output File: amy_15_12_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 173
# 	Output File: amy_15_13_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 174
# 	Output File: amy_16_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 175
# 	Output File: amy_16_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 176
# 	Output File: amy_16_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 177
# 	Output File: amy_16_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 178
# 	Output File: amy_16_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 179
# 	Output File: amy_16_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 180
# 	Output File: amy_16_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 181
# 	Output File: amy_16_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 182
# 	Output File: amy_16_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 183
# 	Output File: amy_1_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 184
# 	Output File: amy_1_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 185
# 	Output File: amy_1_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 186
# 	Output File: amy_1_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 187
# 	Output File: amy_1_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 188
# 	Output File: amy_2_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 189
# 	Output File: amy_2_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 190
# 	Output File: amy_2_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 191
# 	Output File: amy_2_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 192
# 	Output File: amy_2_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 193
# 	Output File: amy_2_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 194
# 	Output File: amy_2_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 195
# 	Output File: amy_2_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 196
# 	Output File: amy_3_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 197
# 	Output File: amy_3_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 198
# 	Output File: amy_3_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 199
# 	Output File: amy_3_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 200
# 	Output File: amy_3_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 201
# 	Output File: amy_3_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 202
# 	Output File: amy_4_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 203
# 	Output File: amy_4_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 204
# 	Output File: amy_4_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 205
# 	Output File: amy_4_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 206
# 	Output File: amy_4_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 207
# 	Output File: amy_4_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 208
# 	Output File: amy_4_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 209
# 	Output File: amy_4_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 210
# 	Output File: amy_4_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 211
# 	Output File: amy_4_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 212
# 	Output File: amy_4_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 213
# 	Output File: amy_5_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 214
# 	Output File: amy_5_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 215
# 	Output File: amy_5_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 216
# 	Output File: amy_5_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 217
# 	Output File: amy_5_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 218
# 	Output File: amy_5_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 219
# 	Output File: amy_5_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 220
# 	Output File: amy_6_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 221
# 	Output File: amy_6_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 222
# 	Output File: amy_6_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 223
# 	Output File: amy_6_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 224
# 	Output File: amy_6_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 225
# 	Output File: amy_6_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 226
# 	Output File: amy_6_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 227
# 	Output File: amy_6_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 228
# 	Output File: amy_7_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 229
# 	Output File: amy_7_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 230
# 	Output File: amy_7_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 231
# 	Output File: amy_7_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 232
# 	Output File: amy_7_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 233
# 	Output File: amy_7_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 234
# 	Output File: amy_7_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 235
# 	Output File: amy_7_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 236
# 	Output File: amy_8_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 237
# 	Output File: amy_8_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 238
# 	Output File: amy_8_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 239
# 	Output File: amy_8_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 240
# 	Output File: amy_8_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 241
# 	Output File: amy_8_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 242
# 	Output File: amy_8_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 243
# 	Output File: amy_8_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 244
# 	Output File: amy_8_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 245
# 	Output File: amy_9_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 246
# 	Output File: amy_9_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 247
# 	Output File: amy_9_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 248
# 	Output File: amy_9_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 249
# 	Output File: amy_9_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 250
# 	Output File: amy_9_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 251
# 	Output File: amy_9_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 252
# 	Output File: amy_9_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 253
# 	Output File: amy_9_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 254
# 	Output File: annar_1_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 255
# 	Output File: annar_1_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 256
# 	Output File: annar_1_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 257
# 	Output File: annar_1_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 258
# 	Output File: annar_1_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 259
# 	Output File: annar_1_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 260
# 	Output File: annar_2_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 261
# 	Output File: annar_2_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 262
# 	Output File: annar_2_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 263
# 	Output File: annar_2_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 264
# 	Output File: annar_2_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 265
# 	Output File: annar_2_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 266
# 	Output File: annar_2_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 267
# 	Output File: annar_2_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 268
# 	Output File: annar_3_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 269
# 	Output File: annar_3_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 270
# 	Output File: annar_3_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 271
# 	Output File: annar_3_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 272
# 	Output File: annar_3_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 273
# 	Output File: annar_3_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 274
# 	Output File: annar_3_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 275
# 	Output File: annar_4_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 276
# 	Output File: annar_4_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 277
# 	Output File: annar_4_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 278
# 	Output File: annar_4_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 279
# 	Output File: annar_4_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 280
# 	Output File: annar_4_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 281
# 	Output File: annar_4_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 282
# 	Output File: annar_4_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 283
# 	Output File: annar_4_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 284
# 	Output File: annar_4_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 285
# 	Output File: annar_5_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 286
# 	Output File: annar_5_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 287
# 	Output File: annar_5_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 288
# 	Output File: annar_5_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 289
# 	Output File: annar_5_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 290
# 	Output File: annar_5_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 291
# 	Output File: annar_5_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 292
# 	Output File: annar_5_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 293
# 	Output File: ariel_1_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 294
# 	Output File: ariel_1_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 295
# 	Output File: ariel_1_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 296
# 	Output File: ariel_1_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 297
# 	Output File: ariel_1_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 298
# 	Output File: ariel_1_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 299
# 	Output File: ariel_1_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 300
# 	Output File: ariel_2_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 301
# 	Output File: ariel_2_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 302
# 	Output File: ariel_2_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 303
# 	Output File: ariel_2_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 304
# 	Output File: ariel_2_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 305
# 	Output File: ariel_2_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 306
# 	Output File: ariel_2_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 307
# 	Output File: ariel_2_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 308
# 	Output File: ariel_3_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 309
# 	Output File: ariel_3_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 310
# 	Output File: ariel_3_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 311
# 	Output File: ariel_3_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 312
# 	Output File: ariel_3_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 313
# 	Output File: ariel_3_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 314
# 	Output File: ariel_3_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 315
# 	Output File: ariel_3_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 316
# 	Output File: ariel_3_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 317
# 	Output File: ariel_3_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 318
# 	Output File: ariel_4_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 319
# 	Output File: ariel_4_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 320
# 	Output File: ariel_4_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 321
# 	Output File: ariel_4_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 322
# 	Output File: ariel_4_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 323
# 	Output File: ariel_4_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 324
# 	Output File: ariel_4_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 325
# 	Output File: ariel_4_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 326
# 	Output File: ariel_4_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 327
# 	Output File: ariel_5_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 328
# 	Output File: ariel_5_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 329
# 	Output File: ariel_5_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 330
# 	Output File: ariel_5_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 331
# 	Output File: ariel_5_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 332
# 	Output File: ariel_5_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 333
# 	Output File: ariel_5_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 334
# 	Output File: ariel_5_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 335
# 	Output File: ariel_5_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 336
# 	Output File: bobon_1_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 337
# 	Output File: bobon_1_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 338
# 	Output File: bobon_1_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 339
# 	Output File: bobon_1_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 340
# 	Output File: bobon_1_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 341
# 	Output File: bobon_1_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 342
# 	Output File: bobon_1_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 343
# 	Output File: bobon_1_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 344
# 	Output File: bobon_1_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 345
# 	Output File: bobon_1_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 346
# 	Output File: bobon_1_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 347
# 	Output File: bobon_1_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 348
# 	Output File: bobon_1_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 349
# 	Output File: bobon_1_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 350
# 	Output File: bobon_2_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 351
# 	Output File: bobon_2_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 352
# 	Output File: bobon_2_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 353
# 	Output File: bobon_2_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 354
# 	Output File: bobon_2_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 355
# 	Output File: bobon_2_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 356
# 	Output File: bobon_2_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 357
# 	Output File: bobon_2_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 358
# 	Output File: bobon_2_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 359
# 	Output File: bobon_3_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 360
# 	Output File: bobon_3_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 361
# 	Output File: bobon_3_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 362
# 	Output File: bobon_3_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 363
# 	Output File: bobon_3_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 364
# 	Output File: bobon_3_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 365
# 	Output File: bobon_3_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 366
# 	Output File: bobon_3_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 367
# 	Output File: bobon_3_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 368
# 	Output File: bobon_3_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 369
# 	Output File: bobon_4_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 370
# 	Output File: bobon_4_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 371
# 	Output File: bobon_4_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 372
# 	Output File: bobon_4_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 373
# 	Output File: bobon_4_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 374
# 	Output File: bobon_4_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 375
# 	Output File: bobon_4_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 376
# 	Output File: bobon_4_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 377
# 	Output File: bobon_5_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 378
# 	Output File: bobon_5_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 379
# 	Output File: bobon_5_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 380
# 	Output File: bobon_5_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 381
# 	Output File: bobon_5_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 382
# 	Output File: bobon_5_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 383
# 	Output File: bobon_5_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 384
# 	Output File: bobon_5_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 385
# 	Output File: bobon_5_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 386
# 	Output File: bobon_5_12_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 387
# 	Output File: bobon_5_12_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 388
# 	Output File: bug_1_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 389
# 	Output File: bug_1_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 390
# 	Output File: bug_2_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 391
# 	Output File: bug_2_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 392
# 	Output File: bug_2_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 393
# 	Output File: bug_2_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 394
# 	Output File: bug_2_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 395
# 	Output File: bug_2_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 396
# 	Output File: bug_3_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 397
# 	Output File: bug_3_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 398
# 	Output File: bug_3_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 399
# 	Output File: bug_3_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 400
# 	Output File: bug_3_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 401
# 	Output File: bug_3_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 402
# 	Output File: bug_3_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 403
# 	Output File: bug_3_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 404
# 	Output File: bug_3_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 405
# 	Output File: bug_3_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 406
# 	Output File: bug_3_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 407
# 	Output File: bug_3_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 408
# 	Output File: bug_3_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 409
# 	Output File: bug_4_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 410
# 	Output File: bug_4_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 411
# 	Output File: bug_4_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 412
# 	Output File: bug_5_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 413
# 	Output File: bug_5_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 414
# 	Output File: bug_5_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 415
# 	Output File: bug_5_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 416
# 	Output File: bug_5_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 417
# 	Output File: bug_5_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 418
# 	Output File: bug_5_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 419
# 	Output File: bug_5_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 420
# 	Output File: bug_5_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 421
# 	Output File: bug_5_11_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 422
# 	Output File: bug_5_12_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 423
# 	Output File: bug_5_13_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 424
# 	Output File: bug_5_14_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 425
# 	Output File: davidson_1_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 426
# 	Output File: davidson_1_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 427
# 	Output File: davidson_1_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 428
# 	Output File: davidson_1_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 429
# 	Output File: davidson_1_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 430
# 	Output File: davidson_1_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 431
# 	Output File: davidson_1_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 432
# 	Output File: davidson_1_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 433
# 	Output File: davidson_1_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 434
# 	Output File: davidson_1_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 435
# 	Output File: davidson_1_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 436
# 	Output File: davidson_1_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 437
# 	Output File: davidson_2_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 438
# 	Output File: davidson_2_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 439
# 	Output File: davidson_2_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 440
# 	Output File: davidson_2_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 441
# 	Output File: davidson_2_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 442
# 	Output File: davidson_2_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 443
# 	Output File: davidson_2_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 444
# 	Output File: davidson_2_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 445
# 	Output File: davidson_2_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 446
# 	Output File: davidson_2_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 447
# 	Output File: davidson_3_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 448
# 	Output File: davidson_3_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 449
# 	Output File: davidson_3_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 450
# 	Output File: davidson_3_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 451
# 	Output File: davidson_3_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 452
# 	Output File: davidson_3_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 453
# 	Output File: davidson_3_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 454
# 	Output File: davidson_3_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 455
# 	Output File: davidson_3_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 456
# 	Output File: davidson_3_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 457
# 	Output File: davidson_3_11_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 458
# 	Output File: davidson_3_11_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 459
# 	Output File: davidson_3_12_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 460
# 	Output File: davidson_3_13_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 461
# 	Output File: davidson_3_13_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 462
# 	Output File: davidson_3_13_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 463
# 	Output File: davidson_3_14_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 464
# 	Output File: davidson_3_14_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 465
# 	Output File: davidson_4_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 466
# 	Output File: davidson_4_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 467
# 	Output File: davidson_4_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 468
# 	Output File: davidson_4_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 469
# 	Output File: davidson_4_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 470
# 	Output File: davidson_4_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 471
# 	Output File: davidson_4_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 472
# 	Output File: davidson_5_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 473
# 	Output File: davidson_5_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 474
# 	Output File: davidson_5_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 475
# 	Output File: davidson_5_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 476
# 	Output File: davidson_5_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 477
# 	Output File: davidson_5_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 478
# 	Output File: davidson_5_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 479
# 	Output File: davidson_5_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 480
# 	Output File: fdps_1_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 481
# 	Output File: fdps_1_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 482
# 	Output File: fdps_1_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 483
# 	Output File: fdps_1_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 484
# 	Output File: fdps_1_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 485
# 	Output File: fdps_1_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 486
# 	Output File: fdps_1_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 487
# 	Output File: fdps_1_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 488
# 	Output File: fdps_1_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 489
# 	Output File: fdps_1_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 490
# 	Output File: fdps_1_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 491
# 	Output File: fdps_1_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 492
# 	Output File: fdps_1_11_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 493
# 	Output File: fdps_1_11_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 494
# 	Output File: fdps_1_12_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 495
# 	Output File: fdps_1_13_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 496
# ...
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 834
# 	Output File: stool_1_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 835
# 	Output File: stool_1_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 836
# 	Output File: stool_1_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 837
# 	Output File: stool_2_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 838
# 	Output File: stool_2_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 839
# 	Output File: stool_2_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 840
# 	Output File: stool_2_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 841
# 	Output File: stool_2_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 842
# 	Output File: stool_2_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 843
# 	Output File: stool_2_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 844
# 	Output File: stool_2_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 845
# 	Output File: stool_2_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 846
# 	Output File: stool_3_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 847
# 	Output File: stool_3_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 848
# 	Output File: stool_3_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 849
# 	Output File: stool_3_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 850
# 	Output File: stool_3_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 851
# 	Output File: stool_3_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 852
# 	Output File: stool_3_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 853
# 	Output File: stool_3_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 854
# 	Output File: stool_4_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 855
# 	Output File: stool_4_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 856
# 	Output File: stool_4_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 857
# 	Output File: stool_4_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 858
# 	Output File: stool_4_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 859
# 	Output File: stool_5_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 860
# 	Output File: stool_5_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 861
# 	Output File: stool_5_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 862
# 	Output File: stool_5_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 863
# 	Output File: stool_5_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 864
# 	Output File: stool_5_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 865
# 	Output File: stool_5_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 866
# 	Output File: stool_5_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 867
# 	Output File: stool_5_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 868
# 	Output File: stool_5_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 869
# 	Output File: stool_5_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 870
# 	Output File: tammy_1_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 871
# 	Output File: tammy_1_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 872
# 	Output File: tammy_1_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 873
# 	Output File: tammy_1_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 874
# 	Output File: tammy_1_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 875
# 	Output File: tammy_1_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 876
# 	Output File: tammy_1_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 877
# 	Output File: titon_1_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 878
# 	Output File: titon_1_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 879
# 	Output File: titon_1_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 880
# 	Output File: titon_1_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 881
# 	Output File: titon_1_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 882
# 	Output File: titon_1_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 883
# 	Output File: titon_1_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 884
# 	Output File: titon_1_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 885
# 	Output File: titon_2_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 886
# 	Output File: titon_2_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 887
# 	Output File: titon_2_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 888
# 	Output File: titon_2_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 889
# 	Output File: titon_2_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 890
# 	Output File: titon_2_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 891
# 	Output File: titon_2_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 892
# 	Output File: titon_2_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 893
# 	Output File: titon_2_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 894
# 	Output File: titon_2_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 895
# 	Output File: titon_2_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 896
# 	Output File: titon_3_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 897
# 	Output File: titon_3_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 898
# 	Output File: titon_3_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 899
# 	Output File: titon_3_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 900
# 	Output File: titon_3_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 901
# 	Output File: titon_3_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 902
# 	Output File: titon_3_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 903
# 	Output File: titon_3_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 904
# 	Output File: titon_3_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 905
# 	Output File: titon_3_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 906
# 	Output File: titon_4_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 907
# 	Output File: titon_4_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 908
# 	Output File: titon_4_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 909
# 	Output File: titon_4_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 910
# 	Output File: titon_4_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 911
# 	Output File: titon_4_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 912
# 	Output File: titon_4_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 913
# 	Output File: titon_4_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 914
# 	Output File: titon_5_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 915
# 	Output File: titon_5_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 916
# 	Output File: titon_5_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 917
# 	Output File: titon_5_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 918
# 	Output File: titon_5_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 919
# 	Output File: titon_5_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 920
# 	Output File: titon_5_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 921
# 	Output File: titon_5_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 922
# 	Output File: titon_5_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 923
# 	Output File: titon_5_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 924
# 	Output File: titon_5_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 925
# 	Output File: titon_5_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 926
# 	Output File: titon_5_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 927
# 	Output File: titon_5_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 928
# 	Output File: yifen_1_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 929
# 	Output File: yifen_1_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 930
# 	Output File: yifen_1_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 931
# 	Output File: yifen_1_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 932
# 	Output File: yifen_1_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 933
# 	Output File: yifen_1_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 934
# 	Output File: yifen_1_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 935
# 	Output File: yifen_1_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 936
# 	Output File: yifen_1_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 937
# 	Output File: yifen_1_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 938
# 	Output File: yifen_1_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 939
# 	Output File: yifen_1_11_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 940
# 	Output File: yifen_1_12_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 941
# 	Output File: yifen_1_14_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 942
# 	Output File: yifen_1_14_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 943
# 	Output File: yifen_1_15_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 944
# 	Output File: yifen_2_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 945
# 	Output File: yifen_2_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 946
# 	Output File: yifen_2_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 947
# 	Output File: yifen_2_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 948
# 	Output File: yifen_2_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 949
# 	Output File: yifen_2_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 950
# 	Output File: yifen_2_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 951
# 	Output File: yifen_2_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 952
# 	Output File: yifen_2_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 953
# 	Output File: yifen_2_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 954
# 	Output File: yifen_2_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 955
# 	Output File: yifen_2_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 956
# 	Output File: yifen_2_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 957
# 	Output File: yifen_2_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 958
# 	Output File: yifen_2_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 959
# 	Output File: yifen_2_12_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 960
# 	Output File: yifen_2_13_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 961
# 	Output File: yifen_2_15_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 962
# 	Output File: yifen_2_15_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 963
# 	Output File: yifen_3_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 964
# 	Output File: yifen_3_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 965
# 	Output File: yifen_3_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 966
# 	Output File: yifen_3_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 967
# 	Output File: yifen_3_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 968
# 	Output File: yifen_3_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 969
# 	Output File: yifen_3_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 970
# 	Output File: yifen_3_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 971
# 	Output File: yifen_3_08_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 972
# 	Output File: yifen_3_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 973
# 	Output File: yifen_3_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 974
# 	Output File: yifen_3_11_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 975
# 	Output File: yifen_4_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 976
# 	Output File: yifen_4_01_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 977
# 	Output File: yifen_4_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 978
# 	Output File: yifen_4_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 979
# 	Output File: yifen_4_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 980
# 	Output File: yifen_4_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 981
# 	Output File: yifen_4_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 982
# 	Output File: yifen_4_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 983
# 	Output File: yifen_4_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 984
# 	Output File: yifen_4_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 985
# 	Output File: yifen_4_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 986
# 	Output File: yifen_4_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 987
# 	Output File: yifen_5_02_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 988
# 	Output File: yifen_5_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 989
# 	Output File: yifen_5_03_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 990
# 	Output File: yifen_5_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 991
# 	Output File: yifen_5_04_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 992
# 	Output File: yifen_5_05_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 993
# 	Output File: yifen_5_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 994
# 	Output File: yifen_5_06_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 995
# 	Output File: yifen_5_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 996
# 	Output File: yifen_5_07_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 997
# 	Output File: yifen_5_09_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 998
# 	Output File: yifen_5_10_voice_output.wav
# (1, 100, 1024)
# (1, 100, 1024)
# Index: 999
# 	Output File: yifen_5_11_voice_output.wav

# %%
# STFT Process Variables, also used in LSTM
sequence_length = 100
stft_size = 1024
batch_size = 1          # Set 1 for process 1 Wav file a time.

# Tensorflow vars + Graph and LSTM Params
input_data = tf.placeholder(tf.float32, [None, sequence_length, stft_size])
sequence_length_tensor = tf.placeholder(tf.int32, (None))

# TF Graph Definition
lstm_cell = tf.contrib.rnn.BasicLSTMCell(stft_size, forget_bias = 1.0, state_is_tuple = True)
init_state = lstm_cell.zero_state(batch_size, tf.float32)
rnn_outputs, final_state = tf.nn.dynamic_rnn(lstm_cell, input_data, sequence_length=sequence_length_tensor, initial_state=init_state, time_major=False)
saver = tf.train.Saver()

# Initialize TF Graph and Restore the Graph
init_op = tf.global_variables_initializer()  # initialize_all_variables()
gpu_options = tf.GPUOptions(allow_growth = True)            # Set session GPU using growing.
sess = tf.Session(config = tf.ConfigProto(gpu_options = gpu_options))
sess.run(init_op)
saver.restore(sess, graphPath)
print("\t***** TF GRAPH RESTORED *****")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-0f77672ed951> in <module>()
#      11 lstm_cell = tf.contrib.rnn.BasicLSTMCell(stft_size, forget_bias = 1.0, state_is_tuple = True)
#      12 init_state = lstm_cell.zero_state(batch_size, tf.float32)
# ---> 13 rnn_outputs, final_state = tf.nn.dynamic_rnn(lstm_cell, input_data, sequence_length=sequence_length_tensor, initial_state=init_state, time_major=False)
#      14 saver = tf.train.Saver()
#      15
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/util/deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/rnn.py in dynamic_rnn(cell, inputs, sequence_length, initial_state, dtype, parallel_iterations, swap_memory, time_major, scope)
#     705         swap_memory=swap_memory,
#     706         sequence_length=sequence_length,
# --> 707         dtype=dtype)
#     708
#     709     # Outputs of _dynamic_rnn_loop are always shaped [time, batch, depth].
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/rnn.py in _dynamic_rnn_loop(cell, inputs, initial_state, parallel_iterations, swap_memory, sequence_length, dtype)
#     914       parallel_iterations=parallel_iterations,
#     915       maximum_iterations=time_steps,
# --> 916       swap_memory=swap_memory)
#     917
#     918   # Unpack final output if not using output tuples.
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/control_flow_ops.py in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2751       ops.add_to_collection(ops.GraphKeys.WHILE_CONTEXT, loop_context)
#    2752     result = loop_context.BuildLoop(cond, body, loop_vars, shape_invariants,
# -> 2753                                     return_same_structure)
#    2754     if maximum_iterations is not None:
#    2755       return result[1]
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/control_flow_ops.py in BuildLoop(self, pred, body, loop_vars, shape_invariants, return_same_structure)
#    2243       with ops.get_default_graph()._mutation_lock():  # pylint: disable=protected-access
#    2244         original_body_result, exit_vars = self._BuildLoop(
# -> 2245             pred, body, original_loop_vars, loop_vars, shape_invariants)
#    2246     finally:
#    2247       self.Exit()
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/control_flow_ops.py in _BuildLoop(self, pred, body, original_loop_vars, loop_vars, shape_invariants)
#    2168         expand_composites=True)
#    2169     pre_summaries = ops.get_collection(ops.GraphKeys._SUMMARY_COLLECTION)  # pylint: disable=protected-access
# -> 2170     body_result = body(*packed_vars_for_body)
#    2171     post_summaries = ops.get_collection(ops.GraphKeys._SUMMARY_COLLECTION)  # pylint: disable=protected-access
#    2172     if not nest.is_sequence_or_composite(body_result):
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/control_flow_ops.py in <lambda>(i, lv)
#    2703         cond = lambda i, lv: (  # pylint: disable=g-long-lambda
#    2704             math_ops.logical_and(i < maximum_iterations, orig_cond(*lv)))
# -> 2705         body = lambda i, lv: (i + 1, orig_body(*lv))
#    2706       try_to_pack = False
#    2707
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/rnn.py in _time_step(time, output_ta_t, state)
#     880           call_cell=call_cell,
#     881           state_size=state_size,
# --> 882           skip_conditionals=True)
#     883     else:
#     884       (output, new_state) = call_cell()
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/rnn.py in _rnn_step(time, sequence_length, min_sequence_length, max_sequence_length, zero_output, state, call_cell, state_size, skip_conditionals)
#     281     # steps.  This is faster when max_seq_len is equal to the number of unrolls
#     282     # (which is typical for dynamic_rnn).
# --> 283     new_output, new_state = call_cell()
#     284     nest.assert_same_structure(zero_output, new_output)
#     285     nest.assert_same_structure(state, new_state)
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/rnn.py in <lambda>()
#     868     if is_keras_rnn_cell and not nest.is_sequence(state):
#     869       state = [state]
# --> 870     call_cell = lambda: cell(input_t, state)
#     871
#     872     if sequence_length is not None:
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/rnn_cell_impl.py in __call__(self, inputs, state, scope, *args, **kwargs)
#     384     # method.  See the class docstring for more details.
#     385     return base_layer.Layer.__call__(
# --> 386         self, inputs, state, scope=scope, *args, **kwargs)
#     387
#     388
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/base.py in __call__(self, inputs, *args, **kwargs)
#     546
#     547       # Actually call layer
# --> 548       outputs = super(Layer, self).__call__(inputs, *args, **kwargs)
#     549
#     550     if not context.executing_eagerly():
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     822           # Build layer if applicable (if the `build` method has been
#     823           # overridden).
# --> 824           self._maybe_build(inputs)
#     825           cast_inputs = self._maybe_cast_inputs(inputs)
#     826
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/engine/base_layer.py in _maybe_build(self, inputs)
#    2144         # operations.
#    2145         with tf_utils.maybe_init_scope(self):
# -> 2146           self.build(input_shapes)
#    2147       # We must set self.built since user defined build functions are not
#    2148       # constrained to set self.built.
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/utils/tf_utils.py in wrapper(instance, input_shape)
#     304     if input_shape is not None:
#     305       input_shape = convert_shapes(input_shape, to_tuples=True)
# --> 306     output_shape = fn(instance, input_shape)
#     307     # Return shapes from `fn` as TensorShapes.
#     308     if output_shape is not None:
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/rnn_cell_impl.py in build(self, inputs_shape)
#     733     self._kernel = self.add_variable(
#     734         _WEIGHTS_VARIABLE_NAME,
# --> 735         shape=[input_depth + h_depth, 4 * self._num_units])
#     736     self._bias = self.add_variable(
#     737         _BIAS_VARIABLE_NAME,
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/util/deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/engine/base_layer.py in add_variable(self, *args, **kwargs)
#    1705   def add_variable(self, *args, **kwargs):
#    1706     """Deprecated, do NOT use! Alias for `add_weight`."""
# -> 1707     return self.add_weight(*args, **kwargs)
#    1708
#    1709   @property
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/base.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, use_resource, synchronization, aggregation, partitioner, **kwargs)
#     459             aggregation=aggregation,
#     460             getter=vs.get_variable,
# --> 461             **kwargs)
#     462
#     463         if regularizer:
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/engine/base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, partitioner, use_resource, synchronization, aggregation, **kwargs)
#     527         collections=collections_arg,
#     528         synchronization=synchronization,
# --> 529         aggregation=aggregation)
#     530     backend.track_variable(variable)
#     531
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/tracking/base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     710         dtype=dtype,
#     711         initializer=initializer,
# --> 712         **kwargs_for_getter)
#     713
#     714     # If we set an initializer and the variable processed it, tracking will not
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/variable_scope.py in get_variable(name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#    1498       constraint=constraint,
#    1499       synchronization=synchronization,
# -> 1500       aggregation=aggregation)
#    1501
#    1502
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/variable_scope.py in get_variable(self, var_store, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#    1241           constraint=constraint,
#    1242           synchronization=synchronization,
# -> 1243           aggregation=aggregation)
#    1244
#    1245   def _get_partitioned_variable(self,
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/variable_scope.py in get_variable(self, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#     565           constraint=constraint,
#     566           synchronization=synchronization,
# --> 567           aggregation=aggregation)
#     568
#     569   def _get_partitioned_variable(self,
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/variable_scope.py in _true_getter(name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, constraint, synchronization, aggregation)
#     517           constraint=constraint,
#     518           synchronization=synchronization,
# --> 519           aggregation=aggregation)
#     520
#     521     synchronization, aggregation, trainable = (
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/variable_scope.py in _get_single_variable(self, name, shape, dtype, initializer, regularizer, partition_info, reuse, trainable, collections, caching_device, validate_shape, use_resource, constraint, synchronization, aggregation)
#     866         tb = [x for x in tb if "tensorflow/python" not in x[0]][:5]
#     867         raise ValueError("%s Originally defined at:\n\n%s" %
# --> 868                          (err_msg, "".join(traceback.format_list(tb))))
#     869       found_var = self._vars[name]
#     870       if not shape.is_compatible_with(found_var.get_shape()):
#
# ValueError: Variable rnn/basic_lstm_cell/kernel already exists, disallowed. Did you mean to set reuse=True or reuse=tf.AUTO_REUSE in VarScope? Originally defined at:
#
#   File "/tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/ops.py", line 1748, in __init__
#     self._traceback = tf_stack.extract_stack()
#   File "/tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/ops.py", line 3426, in _create_op_internal
#     op_def=op_def)
#   File "/tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/ops.py", line 3357, in create_op
#     attrs, op_def, compute_device)
#   File "/tensorflow-1.15.2/python3.6/tensorflow_core/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/op_def_library.py", line 794, in _apply_op_helper
#     op_def=op_def)

# %%
for i in range(7):
  print(i)
