# %% [markdown]
# # set up

# %%
import numpy as np
import scipy.io as sio
import scipy.io.wavfile as wav
import matplotlib.pyplot as plt
import sounddevice as sd

# %%
samplerate, carhorn = wav.read('C:/coffee/airconditional.wav')
#samplerate, engine = wav.read('C:/Users/wallm/Downloads/drive-download-20201019T023851Z-001/engine.wav')
#samplerate, jackhammer = wav.wavfile.read('C:/Users/wallm/Downloads/drive-download-20201019T023851Z-001/jackhammer.wav')

# %%
C:\coffee

# %%
times = np.arange(len(carhorn))/float(samplerate)

#sd.play(carhorn, samplerate)

plt.fill_between(times, carhorn)
plt.xlim(times[0], times[-1])
plt.xlabel('time (s)')
plt.ylabel('amplitude')
plt.show()

# %%
carhorn = carhorn*
#engine = engine*2.5
#jackhammer = jackhammer*2.5

# %%
times = np.arange(len(carhorn))/float(samplerate)

sd.play(carhorn, samplerate)

plt.fill_between(times, carhorn)
plt.xlim(times[0], times[-1])
plt.xlabel('time (s)')
plt.ylabel('amplitude')
plt.show()

# %%
wav.write('C:/coffee/airconditional2.wav', 16000 , carhorn)
#wav.write('C:/Users/wallm/Downloads/drive-download-20201019T023851Z-001/engine2.wav', 16000 , engine)
#wav.write('C:/Users/wallm/Downloads/drive-download-20201019T023851Z-001/jackhammer2.wav', 16000 , jackhammer)

# %%
samplerate, data = wav.read('C:/coffee/file_madedNoise_1.wav')

# %%
times = np.arange(len(data))/float(samplerate)

sd.play(data, samplerate)

plt.fill_between(times, data)
plt.xlim(times[0], times[-1])
plt.xlabel('time (s)')
plt.ylabel('amplitude')
plt.show()

# %%
data = data * 2

# %%
times = np.arange(len(data))/float(samplerate)

sd.play(data, samplerate)

plt.fill_between(times, data)
plt.xlim(times[0], times[-1])
plt.xlabel('time (s)')
plt.ylabel('amplitude')
plt.show()

# %%
samplerate, data = wav.read('C:/coffee/yifen_5_07_voice_hnoise.wav')

# %%
times = np.arange(len(data))/float(samplerate)

sd.play(data, samplerate)

plt.fill_between(times, data)
plt.xlim(times[0], times[-1])
plt.xlabel('time (s)')
plt.ylabel('amplitude')
plt.show()
