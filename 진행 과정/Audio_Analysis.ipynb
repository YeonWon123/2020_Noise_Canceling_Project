# %%
import numpy as np
import librosa, librosa.display 
import matplotlib.pyplot as plt

FIG_SIZE = (15,10)

# %%
file = 'C:/coffee/sound/airconditional.wav'
sig, sr = librosa.load(file, sr=22050)
plt.figure(figsize=FIG_SIZE)
librosa.display.waveplot(sig, sr, alpha=0.5)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Waveform")
print(sr)
# Out:
# 22050

# %%
file = 'C:/coffee/sound/childplaying.wav'
sig, sr = librosa.load(file, sr=22050)
plt.figure(figsize=FIG_SIZE)
librosa.display.waveplot(sig, sr, alpha=0.5)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Waveform")
print(sr)
# Out:
# 22050

# %%
file = 'C:/coffee/sound/drill.wav'
sig, sr = librosa.load(file, sr=22050)
plt.figure(figsize=FIG_SIZE)
librosa.display.waveplot(sig, sr, alpha=0.5)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Waveform")
print(sr)
# Out:
# 22050

# %%
file = 'C:/coffee/NoiseReductionUsingGRU-master/NoiseReductionUsingLSTM/input/abjones_1_01_pnoise.wav'
sig, sr = librosa.load(file, sr=22050)
time = np.linspace(0, len(sig)/sr, len(sig))
plt.subplot(2,4,1)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("input")
librosa.display.waveplot(sig, sr, alpha=0.5)
#plt.plot(time, sig)

file = 'C:/coffee/NoiseReductionUsingGRU-master/NoiseReductionUsingLSTM/output/abjones_1_01_output.wav'
sig, sr = librosa.load(file, sr=22050)
time = np.linspace(0, len(sig)/sr, len(sig))
plt.subplot(2,4,3)
librosa.display.waveplot(sig, sr, alpha=0.5)
#plt.plot(time, sig)

plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("output")
plt.show()

# %%
# load audio file with Librosa
file = 'C:/coffee/NoiseReductionUsingGRU-master/NoiseReductionUsingLSTM/output/abjones_1_01_output.wav'
sig, sr = librosa.load(file, sr=22050)

time = np.linspace(0, len(sig)/sr, len(sig))

ax2 = plt.subplot(1,2,2)
plt.plot(time, sig)
librosa.display.waveplot(sig, sr, alpha=0.5)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Waveform")
# Out:
# Text(0.5, 1.0, 'Waveform')

# %%
plt.show()
